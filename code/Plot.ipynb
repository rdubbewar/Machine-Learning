# %%
import matplotlib.pyplot as plt
import numpy as np
import utils
import pickle
# %matplotlib inline

# %%
FREQ_DIST_FILE = '../train-processed-freqdist.pkl'
BI_FREQ_DIST_FILE = '../train-processed-freqdist-bi.pkl'

# %%
with open(FREQ_DIST_FILE, 'rb') as pkl_file:
    freq_dist = pickle.load(pkl_file)
unigrams = freq_dist.most_common(20)
unigrams
# Out:
# [('b', 1558),
#  ('the', 785),
#  ('to', 604),
#  ('a', 392),
#  ('for', 351),
#  ('and', 342),
#  ('in', 340),
#  ('cubs', 337),
#  ('you', 299),
#  ('of', 262),
#  ('we', 232),
#  ('is', 225),
#  ('on', 201),
#  ('everybodyin', 182),
#  ('at', 175),
#  ('it', 171),
#  ('this', 166),
#  ('happy', 138),
#  ('birthday', 135),
#  ('with', 132)]

# %%
plt.figure(1, [10, 7])
x = np.array(range(0, 40, 2))
y = np.array([i[1] for i in unigrams])
my_xticks = [i[0] for i in unigrams]
plt.xticks(x, my_xticks, rotation=90)
plt.plot(x, y)
plt.show()

# %%
with open(BI_FREQ_DIST_FILE, 'rb') as pkl_file:
    freq_dist = pickle.load(pkl_file)
bigrams = freq_dist.most_common(20)
bigrams
# Out:
# [(('b', 'happy'), 104),
#  (('in', 'the'), 93),
#  (('happy', 'birthday'), 92),
#  (('to', 'the'), 68),
#  (('of', 'the'), 66),
#  (('b', 'cubs'), 66),
#  (('b', 'we'), 61),
#  (('for', 'the'), 59),
#  (('thank', 'you'), 41),
#  (('the', 'cubs'), 36),
#  (('on', 'the'), 31),
#  (('to', 'be'), 28),
#  (('birthday', 'to'), 28),
#  (('for', 'a'), 27),
#  (('for', 'your'), 27),
#  (('b', 'thanks'), 26),
#  (('bplay', 'ball'), 26),
#  (('b', 'the'), 25),
#  (('with', 'the'), 25),
#  (('at', 'the'), 25)]

# %%
plt.figure(1, [10, 7])
x = np.array(range(0, 40, 2))
y = np.array([i[1] for i in bigrams])
my_xticks = [', '.join(i[0]) for i in bigrams]
plt.xticks(x, my_xticks, rotation=90)
plt.plot(x, y)
plt.show()

# %%
with open(FREQ_DIST_FILE, 'rb') as pkl_file:
    freq_dist = pickle.load(pkl_file)
unigrams = freq_dist.most_common(100)
log_ranks = np.log(range(1, 101))
log_freqs = np.log([i[1] for i in unigrams])
z = np.polyfit(log_ranks, log_freqs, 1)
p = np.poly1d(z)
p
# Out:
# poly1d([-0.86905643,  7.40673875])

# %%
classifiers = ['Baseline', 'Naive Bayes', 'Maximum Entropy', 'Decision Tree', 'SVM','Random Forest']
accuracies = [43,73.74,84.25,75.67,71.33,80.67]
plt.figure(4, [8,6])
plt.bar(range(len(classifiers)), accuracies, align='center', alpha=0.5)
plt.xticks(range(len(classifiers)), classifiers, rotation=90)
plt.ylabel('Accuracy')
plt.title('Comparison of Various Classifiers (Unigrams)')
plt.ylim([40, 90])
plt.show()

# %%
classifiers = ['Baseline', 'Naive Bayes', 'Maximum Entropy', 'Decision Tree', 'SVM','Random Forest']
accuracies = [43,74.90,86.27,78.33,76.33,75.33]
plt.figure(4, [8,6])
plt.bar(range(len(classifiers)), accuracies, align='center', alpha=0.5)
plt.xticks(range(len(classifiers)), classifiers, rotation=90)
plt.ylabel('Accuracy')
plt.title('Comparison of Various Classifiers (Unigrams+Bigrams)')
plt.ylim([40, 90])
plt.show()
